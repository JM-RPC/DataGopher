# %%
# %matplotlib tkagg

# %%
# %pwd
# Out:
# '/Users/John/Dev/PythonScripts/DataGopher/srcnew'

# %%
run datagopher.py

# %%
list(globals())
# Out:
# ['__name__',
#  '__doc__',
#  '__package__',
#  '__loader__',
#  '__spec__',
#  '__builtin__',
#  '__builtins__',
#  '_ih',
#  '_oh',
#  '_dh',
#  'In',
#  'Out',
#  'get_ipython',
#  'exit',
#  'quit',
#  'open',
#  '_',
#  '__',
#  '___',
#  '__session__',
#  '_i',
#  '_ii',
#  '_iii',
#  '_i1',
#  '_i2',
#  '_2',
#  '_i3',
#  '__nonzero__',
#  'sys',
#  'pd',
#  'imdl',
#  'tk',
#  'filedialog',
#  'messagebox',
#  'scrolledtext',
#  'ttk',
#  'plt',
#  'np',
#  'godf',
#  'gopt',
#  'gosc',
#  'gopv',
#  'gdata',
#  'datetime',
#  're',
#  'checkName',
#  'goStat',
#  'app',
#  '_i4',
#  '_4',
#  '_i5']

# %%
global_names = list(globals())
print(global_names)
gdata in global_names
gdata = globals()['gdata']
gdata.data.head(10)
# Out:
# ['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', 'open', '_', '__', '___', '__session__', '_i', '_ii', '_iii', '_i1', '_i2', '_2', '_i3', '__nonzero__', 'sys', 'pd', 'imdl', 'tk', 'filedialog', 'messagebox', 'scrolledtext', 'ttk', 'plt', 'np', 'godf', 'gopt', 'gosc', 'gopv', 'gdata', 'datetime', 're', 'checkName', 'goStat', 'app', '_i4', '_4', '_i5', '_5', '_i6']
# 0  RowNumber  Original_Row  carat        cut color clarity  depth  table  \
# 0          0            90   0.70      Ideal     E     SI1   62.5   57.0
# 1          1            91   0.86       Fair     E     SI2   55.1   69.0
# 2          2            93   0.71  Very Good     E     VS2   62.4   57.0
# 3          3            95   0.70       Good     E     VS2   57.5   58.0
# 4          4            98   0.73  Very Good     E     SI1   61.6   59.0
# ...

# %%
globals()['gdata'].data.describe()

# %%
len(df)
