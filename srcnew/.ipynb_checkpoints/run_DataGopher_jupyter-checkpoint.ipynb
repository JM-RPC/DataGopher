# %%
# %matplotlib tkagg

# %%
import os as os
os.getcwd()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 os.getcwd()
#
# NameError: name 'os' is not defined

# %%
run DataGopher.py
# Out:
# install from: https://pypi.org/project/loess/  using pip install loess in your environment.

# %%
list(globals())

# %%
global_names = list(globals())
print(global_names)
gdata in global_names
gdata = globals()['gdata']
gdata.data.head(10)

# %%
run ~/Dev/PythonScripts/getData.py
# Out:
# 2025-11-29 16:13:19.542 python[82558:41570319] The class 'NSOpenPanel' overrides the method identifier.  This method is implemented by class 'NSWindow'

# %%
globals()['gdata'].data.head(10)
# Out:
#    Unnamed: 0   PRICE    ZIP    SQFT  PRICE_PER_SQFT  BEDS  BATHS  \
# 0           0  426000  48108  1908.0           223.0   3.0    3.5
# 1           1  225000  48108  1080.0           208.0   3.0    1.5
# 2           2  470000  48108  3000.0           157.0  30.0   45.0
# 3           3  355000  48108  1637.0           217.0   3.0    2.5
# 4           4  684860  48108  3500.0           196.0   4.0    3.5
# 5           5  655000  48108  3276.0           200.0   5.0    2.5
# 6           6  315000  48108   864.0           365.0   3.0    2.0
# 7           7  475000  48108  3726.0           127.0   4.0    3.5
# 8           8  460000  48108  2018.0           228.0   4.0    2.5
# 9           9  109000  48108   864.0           126.0   3.0    1.0
#
#              CITY   LATITUDE  LONGITUDE  YEAR_BUILT
# 0       Ann Arbor  42.237403 -83.688046      1995.0
# 1       Ann Arbor  42.234612 -83.716912      1971.0
# 2       Ann Arbor  42.240761 -83.704096      2015.0
# 3       Ann Arbor  42.250912 -83.668212      1995.0
# 4  Pittsfield Twp  42.203995 -83.700493      2023.0
# 5       Ann Arbor  42.198648 -83.758332      1988.0
# 6       Ann Arbor  42.234116 -83.713424      1971.0
# 7       Ann Arbor  42.229417 -83.770141      1996.0
# 8       Ann Arbor  42.211470 -83.696103      2004.0
# 9       Ann Arbor  42.233992 -83.710067      1971.0
