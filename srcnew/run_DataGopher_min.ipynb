# %%
# %matplotlib tkagg

# %%
import os as os
os.getcwd()
# Out:
# '/Users/John/Dev/PythonScripts/DataGopher/srcnew'

# %%
run datagopher.py

# %%
globals()['gdata'].data.head(10)

# %%
globals()['gdata'].data.describe()

# %%
type(globals()['gdata'])

# %%
df = globals()['gdata'].data

# %%
df['price_per_carat'] = df['price']/df['carat']
