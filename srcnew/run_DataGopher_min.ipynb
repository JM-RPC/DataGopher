# %% [markdown]
# Start by specifying how matplotlib will communicate with jupyter lab there are other options

# %% [markdown]
# Now run the datagopher application

# %%
# %matplotlib tkagg
# %run datagopher.py

# %%
pwd

# %%
53,058,641,649.996
# Out:
# np.float64(5.991464547107982)

# %%
18568005713.31247 + 162252010351.68753
# Out:
# 180820016065.0
